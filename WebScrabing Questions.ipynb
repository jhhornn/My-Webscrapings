# %%
import os
from bs4 import BeautifulSoup
import requests

# %%
os.chdir(r'C:/Users/hp/Documents/PYTHON/Webscraping')

# %%
url = 'https://www.express.co.uk/life-style/life/1278265/100-general-knowledge-quiz-questions-and-answers'
page = requests.get(url).content
soup = BeautifulSoup(page, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]><html class="lt-ie10 lt-ie9 lt-ie8 lt-ie7 ie" lang="en"> <![endif]-->
# <!--[if IE 7]><html class="lt-ie10 lt-ie9 lt-ie8 ie" lang="en"> <![endif]-->
# <!--[if IE 8]><html class="lt-ie10 lt-ie9 ie" lang="en"> <![endif]-->
# <!--[if IE 9]><html class="lt-ie10 ie" lang="en"> <![endif]-->
# <!--[if gt IE 9]><html class="ie" lang="en"><![endif]-->
# <!--[if !IE]> -->
# <html class="" lang="en">
#  <!-- <![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script>
#    function dynViewport(){var viewport=document.querySelector("meta[name=viewport]");viewport.setAttribute('content','width='+Math.max(window.innerWidth,768))}dynViewport();window.onresize=dynViewport
#   </script>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <link href="https://cdn.images.express.co.uk" rel="dns-prefetch"/>
# ...

# %%
questions = soup.find('div', class_='single-article')#[2:]
quest = questions.find_all('p')#.get_text().split(')')[-1]
for que in quest:
    print(que.text)
#print(quest)
#for question in questions:
    #table = question.find('div', class_='text-description')
    
    #for que in quest:
        #print(que)
# Out:
# We will use your email address only for sending you newsletters. Please see our Privacy Notice for details of your data protection rights.
# With pubs now closing again this month, your usual pub quiz will be moved to the comfort of your own home. If you’re planning a big virtual pub quiz night this week, look no further as Express.co.uk gives you 100 general knowledge questions covering everything from sport to TV, history, geography and the world of celeb for your next round.
# General knowledge questions and answers
# 1) What is the capital of Chile?
# 2) What is the highest mountain in Britain?
# 3) What is the smallest country in the world?
# 4) Alberta is a province of which country?
# 5) How many countries still have the shilling as currency?
# 6) Which is the only vowel not used as the first letter in a US State?
# 7) What is the largest country in the world?
# 8) Where would you find the River Thames?
# 9) What is the hottest continent on Earth?
# ...

# %%
question_header = question.find('h2').text
print(question_header)
# Out:
# Round 10: True or false - Questions

# %%
quest = question.find('p').text.split(')')[-1]
print(quest)
# Out:
#  The Channel Tunnel is the longest rail tunnel in the world

# %%
import re
answer_header = question.find('h2', string = re.compile(r'- Answers')).text
print(answer_header)
# Out:
# Round 10: True or false - Answers

# %%
#answer = question.find('p', string = re.compile(r'Answers')).text
#print(answer)

# %%
for questi in questions:
    quest = questi.find('p').text.split(')')[-1]
    print(quest)
# Out:
# General knowledge questions and answers
#  Santiago
#  What did the Romans call Scotland?
#  What are the five colours of the Olympic rings?
#  Who was the only British Prime Minister to be assassinated?
#  Which nuts are used in marzipan?
#  What is the capital of Westeros in Game of Thrones?
#  One Direction is known for being the runners-up in The X Factor in 2010, but who came first?
#  Which year was the Premier League founded?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-fa93b54441b5> in <module>
#       1 for questi in questions:
# ----> 2     quest = questi.find('p').text.split(')')[-1]
#       3     print(quest)
#       4
#
# AttributeError: 'NoneType' object has no attribute 'text'
